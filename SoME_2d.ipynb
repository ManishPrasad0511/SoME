# %% [markdown]
# <a href="https://colab.research.google.com/github/ManishPrasad0511/SoME/blob/main/SoME_2d.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img style="float: left;padding: 1.0em" src="https://www.3blue1brown.com/favicons/share-thumbnail.jpg" width="300">
#
# #  The Summer of Math Exposition 2022
#
#
# #### 3Blue1Brown

# %%
''' !sudo apt update
# !sudo apt install libcairo2-dev ffmpeg \
    texlive texlive-latex-extra texlive-fonts-extra \
    texlive-latex-recommended texlive-science \
    tipa libpango1.0-dev
# !pip install IPython --upgrade  
# !pip install manim
 '''
# Out:
# Hit:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Get:2 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:4 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:5 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:7 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:10 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,900 kB]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,526 kB]
# Get:12 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [1,063 kB]
# ...

# %%
from manim import *
import numpy as np
import itertools
# Out:
# Manim Community v0.15.2

# %%
a = 8                   # length
b = 6                   # breadth
sides = [a,b]
N = 2                  # Value of N (see the question)
p1 = [-2,1]             # coordinate of 1st point
p2 = [0,-2]             # coordinate of 2nd point
d = 2

# %%
signs  = list(itertools.product([1, -1], repeat=d))
final_pts = []
for i in signs:
  shifted_p2 = p2 + 2*(N-1)*np.multiply(i,sides)
  #print(shifted_p2)
  for j in range(d):
    final_shift = np.zeros(d)
    final_shift[j] = np.multiply(i,2*(sides[j]/2 - i[j]*(p2[j])))[j]
    #print(final_shift)
    final_pts.append(shifted_p2 + final_shift)
#print(final_pts)

# %%
final_coords_all = []
final_coord_out = []
for p in final_pts:

  x_inters = abs(p[0])//(sides[0]/2) - abs(p[0])//sides[0]
  y_inters = abs(p[1])//(sides[1]/2) - abs(p[1])//sides[1]
  m = (p[1]-p1[1]) / (p[0]-p1[0])

  vert_walls = []
  horz_walls = []
  if p[0]>=0:
    x_start = sides[0]/2
  else:
    x_start = -sides[0]/2
  if p[1]>0:
    y_start = sides[1]/2
  else:
    y_start = -sides[1]/2

  for i in np.arange(x_inters):
    y = p1[1] + m*(x_start-p1[0])
    vert_walls.append([x_start,y])
    x_start = x_start + np.sign(p[0])*sides[0]

  for i in np.arange(y_inters):
    x = p1[0] + (y_start-p1[1])/m
    horz_walls.append([x,y_start])
    y_start = y_start + np.sign(p[1])*sides[1]

  all_inters = np.array(vert_walls+horz_walls)
  indexlist =np.argsort(np.linalg.norm(all_inters,axis=1))
  all_inters = all_inters[indexlist]
  final_coord_out.append(all_inters)

  grid_dim = []
  grid_coords = []
  final_coords = []
  for i in range(len(all_inters)):
    all_inters[i] += np.array(sides)/2
    grid_dim.append([all_inters[i][0]%sides[0] , all_inters[i][1]%sides[1]])
    grid_coords.append([all_inters[i][0]//sides[0] , all_inters[i][1]//sides[1]])
    single_final_coord=np.zeros(d)
    for j in range(d):
      if grid_coords[i][j]%2 == 0:
        single_final_coord[j] = (grid_dim[i][j]) - sides[j]/2
      else:
        single_final_coord[j] = sides[j] - (grid_dim[i][j]) - sides[j]/2
    
    final_coords.append(single_final_coord)

  final_coords_all.append(final_coords)

for i in range(len(final_coords_all)):
  for j in range(len(final_coords_all[i])-1,-1,-1):
    if j==len(final_coords_all[i])-1:
      final_coords_all[i].append( np.array(p2) - final_coords_all[i][j])
    if j==0:
      final_coords_all[i][j] -= np.array(p1)
    else:
      final_coords_all[i][j] -=  final_coords_all[i][j-1]

# %%
''' MANDELBROT_COLORS = [
            "#00065c",  #dark blue
            "#061e7e",  #lighter dark blue
            "#0c37a0",  #even lighter dark blue
            "#205abc",  #light blue
            "#4287d3",  #lighter blue
            "#D9EDE4",  #very light nice green
            "#F0F9E4",  #off white
            "#BA9F6A",  #light brown
            "#573706",  #dark brown 
        ] '''
        #rect = Rectangle(width=14.222, height=8)
#np.sign(-6%2)
# Out:
# ' MANDELBROT_COLORS = [\n            "#00065c",  #dark blue\n            "#061e7e",  #lighter dark blue\n            "#0c37a0",  #even lighter dark blue\n            "#205abc",  #light blue\n            "#4287d3",  #lighter blue\n            "#D9EDE4",  #very light nice green\n            "#F0F9E4",  #off white\n            "#BA9F6A",  #light brown\n            "#573706",  #dark brown \n        ] '

# %%
# %%manim whataboutN
# class whataboutN(MovingCameraScene):
#     def construct(self):
#         self.camera.frame.save_state()
#
#         whataboutn = Text("What about N?")
#         self.play(FadeIn(whataboutn))
#         self.wait()
#         self.play(FadeOut(whataboutn))
#
#         equation0 = Tex("Total Reflections ","=","$ 3\\left(N-1\\right) + 1\\left(N\\right)$")
#         equation1 = Tex("=","$4N-3$").next_to(equation0,DOWN)
#         equation2 = Tex("=","$4(N-1)+1$").next_to(equation1,DOWN)
#         eq0 = equation0.get_part_by_tex('=')
#         eq1 = equation1.get_part_by_tex('=').align_to(eq0, LEFT)
#         eq2 = equation2.get_part_by_tex('=').align_to(eq1, LEFT)
#         equation0.get_part_by_tex("Total Reflections ").next_to(eq0, LEFT)
#         equation0.get_part_by_tex("$ 3\\left(N-1\\right) + 1\\left(N\\right)$").next_to(eq0, RIGHT)
#         equation1.get_part_by_tex("$4N-3$").next_to(eq1, RIGHT)
#         equation2.get_part_by_tex("$4(N-1)+1$").next_to(eq2, RIGHT)
#
#         self.play(FadeIn(equation0))
#         brace_1 = Brace(mobject = equation0[2], direction = UP, buff=0.2)
#         brace_1_text = brace_1.get_text("(N-1) on 3 walls, and N on 1 wall")
#         self.play(GrowFromCenter(brace_1), FadeIn(brace_1_text))
#
#         self.play(FadeIn(equation1))
#         self.play(FadeIn(equation2))
#         brace_2 = Brace(mobject = equation2[1], direction = DOWN, buff=0.2)
#         brace_2_text = brace_2.get_text("(N-1) on 4 walls, and 1 extra")
#         self.play(GrowFromCenter(brace_2), FadeIn(brace_2_text))
#         self.wait()
#
#         self.play(FadeOut(equation0,equation1,equation2,brace_1,brace_2,brace_1_text,brace_2_text))
#
#         scale = 12
#         stroke_width_ = 0.5
#         dot = Dot(point=np.array([p1[0],p1[1], 0.])/scale , color=BLUE , radius=0.08/3)
#         d6 = Dot(point=np.array([p2[0], p2[1], 0.])/scale , color=BLUE , radius=0.08/3)
#         all_out_dots = np.array([
#                         [0,2+5*sides[1]],
#                         [sides[0],-2+4*sides[1]],
#                         [2*sides[0],2+3*sides[1]],
#                         [3*sides[0],-2+2*sides[1]],
#                         [4*sides[0],2+1*sides[1]],
#                         [5*sides[0],-2]]
#                         )/scale
#         all_out_dots = [(i - np.array([4*sides[0],4*sides[1]])/scale ) for i in all_out_dots]
#         all_out_dots_mobject = []
#         self.add()
#         for i in all_out_dots:
#           all_out_dots_mobject.append(Dot(point=np.array([i[0],i[1], 0.]) , color=RED , radius=0.08/3))
#         all_images_mobject = []
#         all_images_vgroup = VGroup()
#         for i in range(-8,8+1,1):
#           coloumn_dot=[]
#           for j in range(-8,8+1,1):
#             if i!=-4 or j!=-4:
#               if i%2==0:
#                 coloumn_dot.append(Dot(point = np.array([j*sides[0]+ p2[0], i*sides[1] + p2[1], 0. ]) /scale,  color=RED , radius=0.08/3))
#                 all_images_vgroup.add(coloumn_dot[-1])
#               else:
#                 coloumn_dot.append(Dot(point = np.array([j*sides[0]+ p2[0], i*sides[1] - p2[1], 0. ]) /scale,  color=RED , radius=0.08/3))
#                 all_images_vgroup.add(coloumn_dot[-1])
#
#           all_images_mobject.append(coloumn_dot)
#         all_rects_vgroup = VGroup()
#
#         for i in np.arange(-8*sides[0]/scale ,8*sides[0]/scale+0.1 , sides[0]/scale):
#           row_rects = VGroup()
#           for j in np.arange(-8*sides[1]/scale ,8*sides[1]/scale+0.1 , sides[1]/scale):
#             new_rect = Rectangle(width=sides[0]/scale, height=sides[1]/scale , stroke_width=stroke_width_)
#             new_rect.shift(i*RIGHT,j*UP)
#             row_rects.add(new_rect)
#           all_rects_vgroup.add(row_rects)
#
#         for i in range(len(all_rects_vgroup)):
#           all_rects_vgroup[i][4].set_fill(WHITE, opacity=0.2)
#
#         all_rects_vgroup[4][:].set_fill(WHITE, opacity=0.2)
#         all_rects_vgroup[4][4].set_fill(WHITE, opacity=0.3)
#
#         dot.shift(-4*sides[0]/scale*RIGHT + -4*sides[1]/scale*UP)
#         d6.shift(-4*sides[0]/scale*RIGHT + -4*sides[1]/scale*UP)
#         self.play(FadeIn(dot,d6))
#         self.play(FadeIn(all_rects_vgroup))
#         self.play(FadeIn(all_images_vgroup))
#         self.play(FadeOut(all_images_vgroup))
#         self.play(FadeIn(*all_out_dots_mobject))
#         self.play(FadeOut(*all_out_dots_mobject[:2],*all_out_dots_mobject[4:]))
#
#         N_anim=1
#         self.play(FadeIn(all_rects_vgroup[4+2*N_anim][4+2*N_anim+1].set_fill(WHITE, opacity=0.2),
#                          all_rects_vgroup[4+2*N_anim+1][4+2*N_anim].set_fill(WHITE, opacity=0.2)))
#         self.wait()
#         self.play(FadeIn(all_rects_vgroup[4+2*N_anim][4+2*N_anim].set_fill(WHITE, opacity=0.3)))
#         self.wait()
#
#         all_out_dots_n2 = np.array([
#                           [0*sides[0] ,- 2+9*sides[1]],
#                           [1*sides[0] , 2+8*sides[1]],
#                           [2*sides[0] ,- 2+7*sides[1]],
#                           [3*sides[0] , 2+6*sides[1]],
#                           [4*sides[0] ,- 2+5*sides[1]],
#                           [5*sides[0] , 2+4*sides[1]],
#                           [6*sides[0] ,- 2+3*sides[1]],
#                           [7*sides[0] , 2+2*sides[1]],
#                           [8*sides[0] ,- 2+1*sides[1]],
#                           [9*sides[0], 2+0*sides[1]],])/scale
#         all_out_dots_n2 = [(i - np.array([4*sides[0],4*sides[1]])/scale ) for i in all_out_dots_n2]
#         all_out_dots_mobject_n2 = []
#         for i in all_out_dots_n2:
#           all_out_dots_mobject_n2.append(Dot(point=np.array([i[0],i[1], 0.]) , color=RED , radius=0.08/3))
#         self.play(FadeIn(*all_out_dots_mobject_n2))
#         self.wait()
#         self.play(FadeOut(*all_out_dots_mobject_n2[:4],*all_out_dots_mobject_n2[6:]))
#         self.wait()
#         N_anim=2
#         self.play(FadeIn(all_rects_vgroup[4+2*N_anim][4+2*N_anim+1].set_fill(WHITE, opacity=0.2),
#                          all_rects_vgroup[4+2*N_anim+1][4+2*N_anim].set_fill(WHITE, opacity=0.2)))
#         self.wait()
#         self.play(FadeIn(all_rects_vgroup[4+2*N_anim][4+2*N_anim].set_fill(WHITE, opacity=0.3)))
#         self.wait()
# Out:
# [07/09/22 11:54:02] INFO     Animation 0 : Partial movie file        ]8;id=926085;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=823460;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py#506\506]8;;\
#                              written in '/content/media/videos/conte
#                              nt/1080p60/partial_movie_files/whatabou
#                              tN/1202827926_2198115154_223132457.mp4'
# [07/09/22 11:54:06] INFO     Animation 1 : Partial movie file        ]8;id=653347;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=846209;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py#506\506]8;;\
#                              written in '/content/media/videos/conte
#                              nt/1080p60/partial_movie_files/whatabou
# ...

# %%
# %%manim BigGrid
# class BigGrid(MovingCameraScene):
#     def construct(self):
#         self.camera.frame.save_state()
#
#         my_first_text = Text("Now let's talk about the N=2 case. That is, 2 reflections", font_size=20)
#         second_line = Text("on one wall and 1 reflection on all the others", font_size=20)
#         second_line.next_to(my_first_text,DOWN)
#         self.add(my_first_text, second_line)
#         self.wait(3)
#         self.remove(my_first_text,second_line)
#
#
#         scale = 12
#         stroke_width_ = 0.5
#         dot = Dot(point=np.array([p1[0],p1[1], 0.])/scale , color=BLUE , radius=0.08/3)
#         d6 = Dot(point=np.array([p2[0], p2[1], 0.])/scale , color=BLUE , radius=0.08/3)
#         all_out_dots = np.array([
#                         [0,2+5*sides[1]],
#                         [sides[0],-2+4*sides[1]],
#                         [2*sides[0],2+3*sides[1]],
#                         [3*sides[0],-2+2*sides[1]],
#                         [4*sides[0],2+1*sides[1]],
#                         [5*sides[0],-2],
#
#                         [4*sides[0],2-1*sides[1]],
#                         [3*sides[0],-2-2*sides[1]],
#                         [2*sides[0],2-3*sides[1]],
#                         [sides[0],-2-4*sides[1]],
#                         [0,2-5*sides[1]],
#
#                         [-sides[0],-2-4*sides[1]],
#                         [-2*sides[0],2-3*sides[1]],
#                         [-3*sides[0],-2-2*sides[1]],
#                         [-4*sides[0],2-1*sides[1]],
#
#                         [-5*sides[0],-2],
#                         [-4*sides[0],2+1*sides[1]],
#                         [-3*sides[0],-2+2*sides[1]],
#                         [-2*sides[0],2+3*sides[1]],
#                         [-sides[0],-2+4*sides[1]],
#                         ])/scale
#         all_out_dots_mobject = []
#         for i in all_out_dots:
#           all_out_dots_mobject.append(Dot(point=np.array([i[0],i[1], 0.]) , color=RED , radius=0.08/3))
#         all_images_mobject = []
#         all_images_vgroup = VGroup()
#         for i in range(-8,8+1,1):
#           coloumn_dot=[]
#           for j in range(-8,8+1,1):
#             if i!=0 or j!=0:
#               if i%2==0:
#                 coloumn_dot.append(Dot(point = np.array([j*sides[0]+ p2[0], i*sides[1] + p2[1], 0. ]) /scale,  color=RED , radius=0.08/3))
#                 all_images_vgroup.add(coloumn_dot[-1])
#               else:
#                 coloumn_dot.append(Dot(point = np.array([j*sides[0]+ p2[0], i*sides[1] - p2[1], 0. ]) /scale,  color=RED , radius=0.08/3))
#                 all_images_vgroup.add(coloumn_dot[-1])
#
#           all_images_mobject.append(coloumn_dot)
#
#
#         all_rects = []
#         all_rects_vgroup = VGroup()
#
#         for i in np.arange(-8*sides[0]/scale ,8*sides[0]/scale+0.1 , sides[0]/scale):
#           row_rects = []
#           for j in np.arange(-8*sides[1]/scale ,8*sides[1]/scale+0.1 , sides[1]/scale):
#             new_rect = Rectangle(width=sides[0]/scale, height=sides[1]/scale , stroke_width=stroke_width_)
#             new_rect.shift(i*RIGHT,j*UP)
#             row_rects.append(new_rect)
#             all_rects_vgroup.add(new_rect)
#           all_rects.append(row_rects)
#
#         self.play(self.camera.frame.animate.set(width = all_rects[8][8].width*2).move_to(all_rects[8][8]))
#
#         self.play(FadeIn(dot,d6))
#         self.play(FadeIn(all_rects_vgroup))
#         self.play(FadeIn(all_images_vgroup))
#
#         self.play(self.camera.frame.animate.set(height = all_rects[8][8].height*11).move_to(all_rects[8][8]),run_time = 2)
#
#
#         dot_moving = all_images_mobject[8][8].copy()
#         l1=Line(dot.get_center(),dot_moving.get_center(), stroke_width =1)
#         self.play(FadeIn(dot_moving,l1))
#         dot_moving.generate_target()
#         l1.add_updater(lambda z: z.become(Line(dot.get_center(),dot_moving.get_center())))
#
#         dot_moving.target.move_to(all_images_mobject[10][10])
#         self.play(MoveToTarget(dot_moving),run_time = 2)
#         dot_moving.target.move_to(all_images_mobject[12][4])
#         self.play(MoveToTarget(dot_moving),run_time = 2)
#         dot_moving.target.move_to(all_images_mobject[4][6])
#         self.play(MoveToTarget(dot_moving),run_time = 2)
#         dot_moving.target.move_to(all_images_mobject[6][9])
#         self.play(MoveToTarget(dot_moving),run_time = 2)
#
#         self.wait()
#
#         textbox = VGroup() # create a VGroup
#         box = Rectangle(  # create a box
#             height=0.8, width=8, fill_color=BLUE,
#             fill_opacity=0.5, stroke_color=BLUE
#         ).shift(2*UP)
#         text_in_box = Text("Which of these image points would yeild 5 intersections with the grid?", font_size=15).move_to(box.get_center())
#         textbox.add(box,text_in_box)
#         self.play(FadeIn(textbox))
#         self.wait(4)
#         self.play(FadeOut(textbox,dot_moving,l1))
#
#
#
#         self.play(FadeIn(*all_out_dots_mobject))
#
#
#         lines_outer = []
#         for i in all_out_dots_mobject:
#           lines_outer.append(Line(start=dot.get_center(), end=i.get_center() , color=YELLOW, stroke_width =stroke_width_) )
#         self.play(FadeIn(*lines_outer))
#         self.wait(5)
#
#         self.play(self.camera.frame.animate.set(height = all_rects[11][11].height *7).move_to(all_rects[12][11]))
#         self.wait(5)
#
#         self.play(FadeOut(*lines_outer[6:]))
#         self.wait()
#
#         self.play(FadeOut(*lines_outer[1:6]))
#
#         box = Rectangle(  # create a box
#             height=3, width=2, fill_color=BLUE,
#             fill_opacity=0.5, stroke_color=BLUE
#         ).shift(4*RIGHT+1.5*UP)
#
#         def texttext(text):
#           bruh=VGroup()
#           third_line = Text(text[2], font_size=12).move_to(box.get_center())
#           second_line= Text(text[1], font_size=12).next_to(third_line,UP)
#           first_line = Text(text[0], font_size=12).next_to(second_line,UP)
#           fourth_line= Text(text[3], font_size=12).next_to(third_line,DOWN)
#           fifth_line = Text(text[4], font_size=12).next_to(fourth_line,DOWN)
#           bruh= (first_line, second_line, third_line, fourth_line, fifth_line)
#           return bruh
#
#
#         self.play(FadeIn(box))
#         l=[]
#         text = texttext(['Top wall','Bottom wall','Top wall','Bottom wall','Top wall'])
#         for i in range(8,13):
#           l.append(Line(start=(all_rects[8][i].get_top()-[all_rects[8][i].width/2,0,0]),
#                    end=(all_rects[8][i].get_top()+[all_rects[8][i].width/2  ,0,0]),
#                    color=BLUE, stroke_width =1))
#           self.play(FadeIn(l[-1],text[i-8]))
#         self.wait()
#         self.play(FadeOut(*text,*l,box,lines_outer[0]))
#
#
#         self.play(FadeIn(lines_outer[2],lines_outer[3]))
#         self.wait()
#         self.play(FadeOut(lines_outer[3]))
#         self.play(FadeIn(box))
#         l=[]
#         text = texttext(['Top wall','Right wall','Bottom wall','Top wall','Left wall'])
#         box_coords = [[8,8],[8,9],[9,9],[9,10],[9,11]]
#         l.append(Line(start=all_rects[box_coords[0][0]][box_coords[0][1]].get_top()-[all_rects[8][8].width/2 ,0,0],
#                   end=all_rects[box_coords[0][0]][box_coords[0][1]].get_top()+[all_rects[box_coords[0][0]][box_coords[0][1]].width/2  ,0,0],
#                   color=BLUE, stroke_width =1))
#         self.play(FadeIn(l[-1],text[0]))
#         l.append(Line(start=all_rects[box_coords[1][0]][box_coords[1][1]].get_right()-[0 , all_rects[box_coords[1][0]][box_coords[1][1]].height/2 ,0],
#                   end=all_rects[box_coords[1][0]][box_coords[1][1]].get_right()+[0 , all_rects[box_coords[1][0]][box_coords[1][1]].height/2  ,0],
#                   color=BLUE, stroke_width =1))
#         self.play(FadeIn(l[-1],text[1]))
#         l.append(Line(start=all_rects[box_coords[2][0]][box_coords[2][1]].get_top()-[all_rects[box_coords[2][0]][box_coords[2][1]].width/2  ,0,0],
#                   end=all_rects[box_coords[2][0]][box_coords[2][1]].get_top()+[all_rects[box_coords[2][0]][box_coords[2][1]].width/2  ,0,0],
#                   color=BLUE, stroke_width =1))
#         self.play(FadeIn(l[-1],text[2]))
#         l.append(Line(start=all_rects[box_coords[3][0]][box_coords[3][1]].get_top()-[all_rects[box_coords[3][0]][box_coords[3][1]].width/2  ,0,0],
#                   end=all_rects[box_coords[3][0]][box_coords[3][1]].get_top()+[all_rects[box_coords[3][0]][box_coords[3][1]].width/2  ,0,0],
#                   color=BLUE, stroke_width =1))
#         self.play(FadeIn(l[-1],text[3]))
#         l.append(Line(start=all_rects[box_coords[4][0]][box_coords[4][1]].get_right()-[0, all_rects[box_coords[4][0]][box_coords[4][1]].height/2 ,0],
#                   end=all_rects[box_coords[4][0]][box_coords[4][1]].get_right()+[0, all_rects[box_coords[4][0]][box_coords[4][1]].height/2  ,0],
#                   color=BLUE, stroke_width =1))
#         self.play(FadeIn(l[-1],text[4]))
#
#         self.wait()
#         self.play(FadeOut(*text,*l,box,lines_outer[2]))
#         self.wait()
#
#         self.play(FadeIn(lines_outer[3],box))
#         l=[]
#         text = texttext(['Top wall','Right wall','Left wall','Right wall','Bottom wall'])
#         box_coords = [[8,8],[8,9],[9,9],[10,9],[11,9]]
#         l.append(Line(start=all_rects[box_coords[0][0]][box_coords[0][1]].get_top()-[all_rects[box_coords[0][0]][box_coords[0][1]].width/2  ,0,0],
#                   end=all_rects[box_coords[0][0]][box_coords[0][1]].get_top()+[all_rects[box_coords[0][0]][box_coords[0][1]].width/2  ,0,0],
#                   color=BLUE, stroke_width =1))
#         self.play(FadeIn(l[-1],text[0]))
#         l.append(Line(start=all_rects[box_coords[1][0]][box_coords[1][1]].get_right()-[0 , all_rects[box_coords[1][0]][box_coords[1][1]].height/2  ,0],
#                   end=all_rects[box_coords[1][0]][box_coords[1][1]].get_right()+[0 , all_rects[box_coords[1][0]][box_coords[1][1]].height/2  ,0],
#                   color=BLUE, stroke_width =1))
#         self.play(FadeIn(l[-1],text[1]))
#         l.append(Line(start=all_rects[box_coords[2][0]][box_coords[2][1]].get_right()-[0, all_rects[box_coords[2][0]][box_coords[2][1]].height/2  ,0],
#                   end=all_rects[box_coords[2][0]][box_coords[2][1]].get_right()+[0, all_rects[box_coords[2][0]][box_coords[2][1]].height/2  ,0],
#                   color=BLUE, stroke_width =1))
#         self.play(FadeIn(l[-1],text[2]))
#         l.append(Line(start=all_rects[box_coords[3][0]][box_coords[3][1]].get_right()-[0, all_rects[box_coords[3][0]][box_coords[3][1]].height/2  ,0],
#                   end=all_rects[box_coords[3][0]][box_coords[3][1]].get_right()+[0, all_rects[box_coords[3][0]][box_coords[3][1]].height/2  ,0],
#                   color=BLUE, stroke_width =1))
#         self.play(FadeIn(l[-1],text[3]))
#         l.append(Line(start=all_rects[box_coords[4][0]][box_coords[4][1]].get_top()-[all_rects[box_coords[4][0]][box_coords[4][1]].width/2  ,0,0],
#                   end=all_rects[box_coords[4][0]][box_coords[4][1]].get_top()+[all_rects[box_coords[4][0]][box_coords[4][1]].width/2  ,0,0],
#                   color=BLUE, stroke_width =1))
#         self.play(FadeIn(l[-1],text[4]))
#         self.wait()
#         self.play(FadeOut(*text,*l,box))
#         self.wait()
#
#
#
#         self.play(self.camera.frame.animate.set(height = all_rects[8][8].height*11).move_to(all_rects[8][8]),run_time = 2)
#         indices_list = [2,3,7,8,12,13,17,18]
#         final_outer_dots = [ all_out_dots_mobject[i] for i in indices_list]
#         final_outer_lines= [ lines_outer[i] for i in indices_list]
#         self.play(FadeIn(*final_outer_dots,*final_outer_lines))
#         self.wait()
# Out:
# ' %%manim BigGrid\nclass BigGrid(MovingCameraScene):\n    def construct(self):\n        self.camera.frame.save_state()\n\n        my_first_text = Text("Now let\'s talk about the N=2 case. That is, 2 reflections", font_size=20)\n        second_line = Text("on one wall and 1 reflection on all the others", font_size=20)\n        second_line.next_to(my_first_text,DOWN)\n        self.add(my_first_text, second_line)\n        self.wait(3)\n        self.remove(my_first_text,second_line)\n       \n\n        scale = 12\n        stroke_width_ = 0.5\n        dot = Dot(point=np.array([p1[0],p1[1], 0.])/scale , color=BLUE , radius=0.08/3)  \n        d6 = Dot(point=np.array([p2[0], p2[1], 0.])/scale , color=BLUE , radius=0.08/3)\n        all_out_dots = np.array([\n                        [0,2+5*sides[1]],\n                        [sides[0],-2+4*sides[1]],\n                        [2*sides[0],2+3*sides[1]],\n                        [3*sides[0],-2+2*sides[1]],\n                        [4*sides[0],2+1
# ...

# %%
# %%manim N1case
# class N1case(MovingCameraScene):
#     def construct(self):
#         self.camera.frame.save_state()
#         scale = 2.5
#
#         rect = Rectangle(width=sides[0]/scale, height=sides[1]/scale)
#
#         dot = Dot(point=np.array([p1[0],p1[1], 0.])/scale , color=BLUE , radius=0.08)
#
#         d6 = Dot(point=np.array([p2[0], p2[1], 0.])/scale , color=BLUE , radius=0.08)
#
#
#         self.add(rect,dot,d6)
#         self.wait(2)
#
#         my_first_text = Text("Consider the N=1 situation. That is, only one reflection ", font_size=20)
#         my_first_text.to_edge(UP)
#         second_line = Text("on one wall before reaching the second point", font_size=20)
#         second_line.next_to(my_first_text,DOWN)
#         third_line = Text("(and no reflections on other walls because N-1=0)", font_size=20)
#         third_line.next_to(second_line,DOWN)
#         fourth_line = Text("There are only four solutions for this case", font_size=20)
#         fourth_line.next_to(third_line,DOWN)
#         self.add(my_first_text, second_line, third_line, fourth_line)
#         self.wait(5)
#         self.play(FadeOut(my_first_text,second_line, third_line, fourth_line))
#
#
#         out_pts = np.array([[0,8],[8,-2],[0,-4],[-8,-2]])/scale
#         int_pts = np.array([[4/7-2,3],[4,-0.8],[-0.4,-3],[-4,0]])/scale
#         out_dots_mobject = []
#         int_dots_mobject = []
#
#         for i in int_pts:
#           int_dots_mobject.append(Dot(  point=np.array([i[0],i[1], 0.]) , color=RED , radius=0.08))
#
#
#         self.play(self.camera.frame.animate.set(width = rect.width*2).move_to(rect))
#         l1 = []
#         l2 = []
#
#         for i in range(len(int_dots_mobject)):
#           l1.append(Line(start=dot.get_center(), end=int_dots_mobject[i].get_center() , color=YELLOW))
#           l2.append(Line(start=int_dots_mobject[i].get_center(), end=d6.get_center() , color=YELLOW))
#           self.play(FadeIn(l1[i]))
#           self.add(int_dots_mobject[i])
#           self.play(FadeIn(l2[i]))
#
#         self.play(Restore(self.camera.frame))
#         self.wait(2)
#         my_first_text = Text("Here's a different way of thinking about the solutions", font_size=20)
#         my_first_text.to_edge(UP)
#         self.add(my_first_text)
#         self.wait(2)
#         self.play(FadeOut(my_first_text))
#
#         my_first_text = Text("Construct the \"mirrored boxes\" ", font_size=20)
#         my_first_text.to_edge(UP)
#         second_line = Text("corresponding to each side of the original box", font_size=20)
#         second_line.next_to(my_first_text,DOWN)
#         self.add(my_first_text, second_line)
#         self.wait(2)
#
#         self.play(FadeOut(*l1,*l2))
#         self.play(FadeOut(*int_dots_mobject))
#         self.play(FadeOut(my_first_text,second_line))
#
#         v_rect = []
#
#         for i in np.arange(-sides[0]/scale , sides[0]/scale+0.1 , 2*sides[0]/scale):
#             new_rect = Rectangle(width=sides[0]/scale, height=sides[1]/scale)
#             new_rect.shift(i*RIGHT)
#             v_rect.append(new_rect)
#
#         for j in np.arange(-sides[1]/scale , sides[1]/scale+0.1 , 2*sides[1]/scale):
#             new_rect = Rectangle(width=sides[0]/scale, height=sides[1]/scale)
#             new_rect.shift(j*UP)
#             v_rect.append(new_rect)
#
#         self.play(FadeIn(*v_rect))
#         self.wait()
#
#         my_first_text = Text("Find the image of the second point", font_size=15)
#         my_first_text.to_corner(UP+LEFT)
#         second_line = Text("in all the mirrored boxes", font_size=15)
#         second_line.next_to(my_first_text,DOWN)
#         self.add(my_first_text, second_line)
#         self.wait(2)
#         self.play(FadeOut(my_first_text,second_line))
#
#
#         for i in out_pts:
#           out_dots_mobject.append(Dot(  point=np.array([i[0],i[1], 0.]) , color=RED , radius=0.08))
#           arrow = Arrow(d6, out_dots_mobject[-1] , color=RED, buff=0)
#           self.play(FadeIn(arrow))
#           self.add(out_dots_mobject[-1])
#           self.play(FadeOut(arrow))
#         l3 = []
#         self.wait(2)
#
#         my_first_text = Text("Join the first point to all these", font_size=15)
#         my_first_text.to_corner(UP+LEFT)
#         second_line = Text("images of the second point", font_size=15)
#         second_line.next_to(my_first_text,DOWN)
#         self.add(my_first_text, second_line)
#         self.wait(2)
#         self.play(FadeOut(my_first_text,second_line))
#
#         for i in range(len(out_dots_mobject)):
#           l3.append(Line(start=int_dots_mobject[i].get_center(), end=out_dots_mobject[i].get_center() , color=YELLOW))
#           self.play(FadeIn(l1[i],l3[i]))
#
#         my_first_text = Text("The rays in all the mirrored boxes are exactly", font_size=15)
#         my_first_text.to_corner(UP+LEFT)
#         second_line = Text("the mirror images of the reflected rays", font_size=15)
#         second_line.next_to(my_first_text,DOWN)
#         third_line = Text("in the initial box", font_size=15)
#         third_line.next_to(second_line,DOWN)
#         self.add(my_first_text, second_line, third_line)
#         self.wait(2)
#
#         self.play(FadeIn(*int_dots_mobject))
#
#         for i in range(len(out_dots_mobject)):
#           self.play(Transform(l3[i],l2[i]))
#
#         self.play(self.camera.frame.animate.set(width = rect.width*2).move_to(rect))
#         self.wait(2)
# Out:
# ' %%manim N1case\nclass N1case(MovingCameraScene):\n    def construct(self):\n        self.camera.frame.save_state()\n        scale = 2.5\n        \n        rect = Rectangle(width=sides[0]/scale, height=sides[1]/scale)\n        \n        dot = Dot(point=np.array([p1[0],p1[1], 0.])/scale , color=BLUE , radius=0.08)\n      \n        d6 = Dot(point=np.array([p2[0], p2[1], 0.])/scale , color=BLUE , radius=0.08)\n        \n\n        self.add(rect,dot,d6)        \n        self.wait(2)  \n\n        my_first_text = Text("Consider the N=1 situation. That is, only one reflection ", font_size=20)\n        my_first_text.to_edge(UP)\n        second_line = Text("on one wall before reaching the second point", font_size=20)\n        second_line.next_to(my_first_text,DOWN)\n        third_line = Text("(and no reflections on other walls because N-1=0)", font_size=20)\n        third_line.next_to(second_line,DOWN)   \n        fourth_line = Text("There are only four solutions for this case", font_size=20)
# ...

# %%
# %%manim CoordSysExample
# class CoordSysExample(MovingCameraScene):
#     def construct(self):
#         self.camera.frame.save_state()
#         scale = 2.5
#
#         rect = Rectangle(width=sides[0]/scale, height=sides[1]/scale)
#         rect.generate_target()
#         rect.target.shift((sides[1]/scale)*DOWN,(sides[0]/scale)*LEFT)
#
#         dot = Dot(point=np.array([p1[0],p1[1], 0.])/scale , color=BLUE , radius=0.08/1)
#         dot.generate_target()
#         dot.target.shift((sides[1]/scale)*DOWN,(sides[0]/scale)*LEFT)
#
#         d6 = Dot(point=np.array([p2[0], p2[1], 0.])/scale , color=BLUE , radius=0.08/1)
#         d6.generate_target()
#         d6.target.shift((sides[1]/scale)*DOWN,(sides[0]/scale)*LEFT)
#
#         self.add(rect,dot,d6)
#         self.play(MoveToTarget(rect),
#                   MoveToTarget(dot),
#                   MoveToTarget(d6))
#         self.wait()
#
#         graphs = []
#         v_rect = []
#
#         for i in np.arange(-sides[0]/scale , sides[0]/scale+0.1 , sides[0]/scale):
#           for j in np.arange(-sides[1]/scale , sides[1]/scale+0.1 , sides[1]/scale):
#             new_rect = Rectangle(width=sides[0]/scale, height=sides[1]/scale)
#             new_rect.shift(i*RIGHT,j*UP)
#             v_rect.append(new_rect)
#
#         self.play(FadeIn(*v_rect))
#         self.wait()
#
#
#         d6.target.shift(2*(sides[1]/scale)*UP,2*(sides[0]/scale)*RIGHT)
#         self.play(MoveToTarget(d6))
#
#         self.wait()
#
#         self.play(FadeIn(Line(start=dot, end=d6)))
#
#         out_dots_mobject=[]
#         int_dots_mobject=[]
#
#         out_dots = (np.array([[2,3],[4,4],[12,8],[14,9],[16,10]])  - np.array(sides))/scale
#         int_dots = (np.array([[2,3],[4,2],[-4,-2],[-2,-3],[0,-2]])   - np.array(sides))/scale
#         for i in out_dots:
#           out_dots_mobject.append(Dot(  point=np.array([i[0],i[1], 0.]) , color=RED , radius=0.08   ))
#           self.play(FadeIn(out_dots_mobject[-1]))
#         for i in int_dots:
#           int_dots_mobject.append(Dot(  point=np.array([i[0],i[1], 0.]) , color=RED , radius=0.08   ))
#
#         self.wait()
#
#
#         self.play(FadeIn(Line(start=dot, end=np.concatenate([int_dots[0],[0]]) , color=YELLOW)))
#
#
#
#
#         og = [0,2,6,8]
#         v_ref = [3,5]
#         h_ref = [1,7]
#         v_h_ref = [4]
#         for i in og:
#            self.play(v_rect[i].animate.set_fill(BLUE, opacity=0.5))
#         for i in v_ref:
#            self.play(v_rect[i].animate.set_fill(RED, opacity=0.5))
#         for i in h_ref:
#            self.play(v_rect[i].animate.set_fill(YELLOW, opacity=0.5))
#         for i in v_h_ref:
#            self.play(v_rect[i].animate.set_fill(PINK, opacity=0.5))
#
#         self.wait()
# Out:
# ' %%manim CoordSysExample\nclass CoordSysExample(MovingCameraScene):\n    def construct(self):\n        self.camera.frame.save_state()\n        scale = 2.5\n        \n        rect = Rectangle(width=sides[0]/scale, height=sides[1]/scale)\n        rect.generate_target()\n        rect.target.shift((sides[1]/scale)*DOWN,(sides[0]/scale)*LEFT)\n        \n        dot = Dot(point=np.array([p1[0],p1[1], 0.])/scale , color=BLUE , radius=0.08/1)\n        dot.generate_target()\n        dot.target.shift((sides[1]/scale)*DOWN,(sides[0]/scale)*LEFT)\n\n        d6 = Dot(point=np.array([p2[0], p2[1], 0.])/scale , color=BLUE , radius=0.08/1)\n        d6.generate_target()\n        d6.target.shift((sides[1]/scale)*DOWN,(sides[0]/scale)*LEFT)\n\n        self.add(rect,dot,d6)\n        self.play(MoveToTarget(rect),\n                  MoveToTarget(dot),\n                  MoveToTarget(d6))\n        self.wait()  \n        \n        graphs = []\n        v_rect = []\n\n        for i in np.arange(-sides[0]/sca
# ...

# %%
# %%manim CoordSysExample
# class CoordSysExample(MovingCameraScene):
#     def construct(self):
#         self.camera.frame.save_state()
#         scale = 2.5
#
#         rect = Rectangle(width=sides[0]/scale, height=sides[1]/scale)
#         rect.generate_target()
#         rect.target.shift((sides[1]/scale)*DOWN,(sides[0]/scale)*LEFT)
#
#         dot = Dot(point=np.array([p1[0],p1[1], 0.])/scale , color=BLUE , radius=0.08/1)
#         dot.generate_target()
#         dot.target.shift((sides[1]/scale)*DOWN,(sides[0]/scale)*LEFT)
#
#         d6 = Dot(point=np.array([p2[0], p2[1], 0.])/scale , color=BLUE , radius=0.08/1)
#         d6.generate_target()
#         d6.target.shift((sides[1]/scale)*DOWN,(sides[0]/scale)*LEFT)
#
#         self.add(rect,dot,d6)
#         self.play(MoveToTarget(rect),
#                   MoveToTarget(dot),
#                   MoveToTarget(d6))
#         self.wait()
#
#         graphs = []
#         v_rect = []
#
#         for i in np.arange(-sides[0]/scale , sides[0]/scale+0.1 , sides[0]/scale):
#           for j in np.arange(-sides[1]/scale , sides[1]/scale+0.1 , sides[1]/scale):
#             new_rect = Rectangle(width=sides[0]/scale, height=sides[1]/scale)
#             new_rect.shift(i*RIGHT,j*UP)
#             v_rect.append(new_rect)
#
#         self.play(FadeIn(*v_rect))
#         self.wait()
#
#
#         d6.target.shift(2*(sides[1]/scale)*UP,2*(sides[0]/scale)*RIGHT)
#         self.play(MoveToTarget(d6))
#
#         self.wait()
#
#
#         l_out = []
#
#
#         out_dots_mobject=[]
#         int_dots_mobject=[]
#
#         out_dots = (np.array([[2,3],[4,4],[12,8],[14,9],[16,10]])  - np.array(sides))/scale
#         int_dots = (np.array([[2,3],[4,2],[-4,-2],[-2,-3],[0,-2]])   - np.array(sides))/scale
#
#
#         for i in range(len(out_dots)):
#           out_dots_mobject.append(Dot(  point=np.array([out_dots[i][0],out_dots[i][1], 0.]) , color=RED , radius=0.08   ))
#           if i==0:
#             l_out.append( Line( start=dot.get_center() , end= out_dots_mobject[-1].get_center() ))
#           else:
#             l_out.append( Line( start=out_dots_mobject[-2].get_center() , end= out_dots_mobject[-1].get_center() ))
#
#
#         for i in int_dots:
#           int_dots_mobject.append(Dot(  point=np.array([i[0],i[1], 0.]) , color=RED , radius=0.08   ))
#
#         self.play(FadeIn(*l_out))
#         self.wait()
#         self.play(FadeIn(*out_dots_mobject))
#
#         l_int = []
#
#         l_int.append(Line(start=dot.get_center(), end=np.concatenate([int_dots[0],[0]]) , color=YELLOW))
#         self.play(FadeIn(l_int[-1]))
#
#
#         arrow = Arrow(np.array([out_dots[1][0], out_dots[1][1], 0]), np.array([out_dots[1][0], int_dots[1][1], 0]) , color=RED, buff=0)
#         self.play(FadeIn(arrow))
#         self.wait()
#         self.play(FadeOut(arrow))
#         self.play(FadeIn(int_dots_mobject[1]), color=RED)
#         self.wait()
#         l_int.append(Line(start=np.concatenate([int_dots[0],[0]]), end=np.concatenate([int_dots[1],[0]]) , color=YELLOW))
#         self.play(FadeIn(l_int[-1]))
#
#
#         arrow = Arrow(np.array([out_dots[2][0], out_dots[2][1], 0]), np.array([out_dots[2][0] - 2*sides[0]/scale, out_dots[2][1], 0]) , color=RED, buff=0)
#         self.play(FadeIn(arrow))
#         self.play(FadeOut(arrow))
#         arrow = Arrow(np.array([out_dots[2][0] - 2*sides[0]/scale, out_dots[2][1], 0])  , np.array([int_dots[2][0], int_dots[2][1], 0]) , color=RED, buff=0)
#         self.play(FadeIn(arrow))
#         self.play(FadeOut(arrow))
#         self.play(FadeIn(int_dots_mobject[2]), color=RED)
#         self.wait()
#         l_int.append(Line(start=np.concatenate([int_dots[1],[0]]), end=np.concatenate([int_dots[2],[0]]) , color=YELLOW))
#         self.play(FadeIn(l_int[-1]))
#
#         arrow = Arrow(np.array([out_dots[3][0], out_dots[3][1], 0]), np.array([sides[0]/scale - out_dots[3][0], out_dots[3][1], 0]) , color=RED, buff=0)
#         self.play(FadeIn(arrow))
#         self.play(FadeOut(arrow))
#         arrow = Arrow(np.array([sides[0]/scale - out_dots[3][0] , out_dots[3][1], 0]), np.array([int_dots[3][0] , out_dots[3][1], 0]) , color=RED, buff=0)
#         self.play(FadeIn(arrow))
#         self.play(FadeOut(arrow))
#         arrow = Arrow(np.array([int_dots[3][0] , out_dots[3][1], 0]), np.array([int_dots[3][0] , int_dots[3][1], 0]) , color=RED, buff=0)
#         self.play(FadeIn(arrow))
#         self.play(FadeOut(arrow))
#         self.play(FadeIn(int_dots_mobject[3]), color=RED)
#         self.wait()
#         l_int.append(Line(start=np.concatenate([int_dots[2],[0]]), end=np.concatenate([int_dots[3],[0]]) , color=YELLOW))
#         self.play(FadeIn(l_int[-1]))
#
#         arrow = Arrow(np.array([out_dots[4][0], out_dots[4][1], 0]), np.array([out_dots[4][0] - sides[0]/scale, out_dots[4][1], 0]) , color=RED, buff=0)
#         self.play(FadeIn(arrow))
#         self.play(FadeOut(arrow))
#         arrow = Arrow(np.array([out_dots[4][0]- sides[0]/scale, out_dots[4][1], 0]), np.array([int_dots[4][0] , out_dots[4][1], 0]) , color=RED, buff=0)
#         self.play(FadeIn(arrow))
#         self.play(FadeOut(arrow))
#         arrow = Arrow(np.array([int_dots[4][0] , out_dots[4][1], 0]), np.array([int_dots[4][0] , sides[1]/scale-out_dots[4][1], 0]) , color=RED, buff=0)
#         self.play(FadeIn(arrow))
#         self.play(FadeOut(arrow))
#         arrow = Arrow(np.array([int_dots[4][0] ,sides[1]/scale-out_dots[4][1], 0]), np.array([int_dots[4][0] , int_dots[4][1], 0]) , color=RED, buff=0)
#         self.play(FadeIn(arrow))
#         self.play(FadeOut(arrow))
#         self.play(FadeIn(Dot(point=np.array([int_dots[-1][0],int_dots[-1][1], 0.]) , color=BLUE , radius=0.08   )))
#         self.wait()
#         l_int.append(Line(start=np.concatenate([int_dots[3],[0]]), end=np.concatenate([int_dots[4],[0]]) , color=YELLOW))
#         self.play(FadeIn(l_int[-1]))
#         self.wait()
#         self.play(FadeOut(*l_int))
#
#         self.play(Transform(l_out[0],l_int[0]),
#                   Transform(l_out[1],l_int[1]),
#                   Transform(l_out[2],l_int[2]),
#                   Transform(l_out[3],l_int[3]),
#                   Transform(l_out[4],l_int[4]),
#                   )
#
#         self.play(self.camera.frame.animate.set(width = rect.width*2).move_to(rect))
#         self.wait()
# Out:
# ' %%manim CoordSysExample\nclass CoordSysExample(MovingCameraScene):\n    def construct(self):\n        self.camera.frame.save_state()\n        scale = 2.5\n        \n        rect = Rectangle(width=sides[0]/scale, height=sides[1]/scale)\n        rect.generate_target()\n        rect.target.shift((sides[1]/scale)*DOWN,(sides[0]/scale)*LEFT)\n        \n        dot = Dot(point=np.array([p1[0],p1[1], 0.])/scale , color=BLUE , radius=0.08/1)\n        dot.generate_target()\n        dot.target.shift((sides[1]/scale)*DOWN,(sides[0]/scale)*LEFT)\n\n        d6 = Dot(point=np.array([p2[0], p2[1], 0.])/scale , color=BLUE , radius=0.08/1)\n        d6.generate_target()\n        d6.target.shift((sides[1]/scale)*DOWN,(sides[0]/scale)*LEFT)\n\n        self.add(rect,dot,d6)\n        self.play(MoveToTarget(rect),\n                  MoveToTarget(dot),\n                  MoveToTarget(d6))\n        self.wait()  \n        \n        graphs = []\n        v_rect = []\n\n        for i in np.arange(-sides[0]/sca
# ...

# %%
scale = 2.5

out_dots = (np.array([[2,3],[4,4],[12,8],[14,9],[16,10]])  - np.array(sides))/scale
out_dots
# Out:
# array([[-2.4, -1.2],
#        [-1.6, -0.8],
#        [ 1.6,  0.8],
#        [ 2.4,  1.2],
#        [ 3.2,  1.6]])

# %%
np.array(sides)/scale
# Out:
# array([3.2, 2.4])

# %%
# %%manim outside_grid
#
# class outside_grid(MovingCameraScene):
#     def construct(self):
#       scale = 3
#       rect = Rectangle(width=sides[0]/scale, height=sides[1]/scale)
#
#       dot = Dot(point=np.array([p1[0],p1[1], 0.])/scale , color=BLUE , radius=0.08/scale)
#       d6 = Dot(point=np.array([p2[0], p2[1], 0.])/scale , color=BLUE , radius=0.08/scale)
#
#       self.camera.frame.save_state()
#       self.play(self.camera.frame.animate.set(width = rect.width*2).move_to(rect))
#       self.add(rect)
#       self.wait()
#       self.add(dot,d6)
#       self.wait()
#
#
#       self.wait()
#       self.play(Restore(self.camera.frame))
#
#       for i in np.arange(-(sides[0]*2 + sides[0]/2)/scale , (sides[0]*2 + sides[0]/2+1)/scale ,sides[0]/scale):
#         self.play(FadeIn(Line(start=np.array([i,-(sides[1]*2 + sides[1]/2)/scale, 0.]), end=np.array([i,(sides[1]*2 + sides[1]/2)/scale, 0.]))))
#
#       for i in np.arange(-(sides[1]*1 + sides[1]/2)/scale , (sides[1]*1 + sides[1]/2+1)/scale ,sides[1]/scale):
#         self.play(FadeIn(Line(start=np.array([-(sides[0]*2 + sides[0]/1)/scale, i, 0.]), end=np.array([(sides[0]*2 + sides[0]/1)/scale, i, 0.]))))
#       self.wait()
# Out:
# ' %%manim outside_grid\n\nclass outside_grid(MovingCameraScene):\n    def construct(self):\n      scale = 3\n      rect = Rectangle(width=sides[0]/scale, height=sides[1]/scale)\n\n      dot = Dot(point=np.array([p1[0],p1[1], 0.])/scale , color=BLUE , radius=0.08/scale)\n      d6 = Dot(point=np.array([p2[0], p2[1], 0.])/scale , color=BLUE , radius=0.08/scale)\n      \n      self.camera.frame.save_state()\n      self.play(self.camera.frame.animate.set(width = rect.width*2).move_to(rect))\n      self.add(rect)\n      self.wait()\n      self.add(dot,d6)\n      self.wait()\n      \n      \n      self.wait()\n      self.play(Restore(self.camera.frame))\n\n      for i in np.arange(-(sides[0]*2 + sides[0]/2)/scale , (sides[0]*2 + sides[0]/2+1)/scale ,sides[0]/scale):\n        self.play(FadeIn(Line(start=np.array([i,-(sides[1]*2 + sides[1]/2)/scale, 0.]), end=np.array([i,(sides[1]*2 + sides[1]/2)/scale, 0.]))))\n\n      for i in np.arange(-(sides[1]*1 + sides[1]/2)/scale , (sides[1]*1 + sides
# ...

# %%
# %%manim rect_mirror
#
# class rect_mirror(Scene):
#     def construct(self):
#       rect = Rectangle(width=sides[0], height=sides[1])
#
#       dot = Dot(point=np.array([p1[0],p1[1], 0.]) , color=BLUE)
#       d6 = Dot(point=np.array([p2[0], p2[1], 0.]) , color=BLUE)
#
#       def update_path(path):
#             previous_path = path.copy()
#             previous_path.add_points_as_corners([dot.get_center()])
#             path.become(previous_path)
#
#       self.add(rect)
#       self.wait()
#       self.add(dot,d6)
#       self.wait()
#
#       #for i in range(2):
#       for i in range(len(final_coords_all)):
#         dot = Dot(point=np.array([p1[0],p1[1], 0.]) , color=BLUE)
#
#         path = VMobject()
#         path.set_points_as_corners([dot.get_center(), dot.get_center()])
#         path.add_updater(update_path)
#
#         self.add(path, dot)
#         dot.generate_target()
#         for j in range(len(final_coords_all[i])):
#           dot.target.shift(final_coords_all[i][j][0]*RIGHT,final_coords_all[i][j][1]*UP)
#           self.play(MoveToTarget(dot))
#
#         self.play(FadeOut(dot,path))
#         self.remove(dot,path)
# Out:
# ' %%manim rect_mirror\n\nclass rect_mirror(Scene):\n    def construct(self):\n      rect = Rectangle(width=sides[0], height=sides[1])\n\n      dot = Dot(point=np.array([p1[0],p1[1], 0.]) , color=BLUE)\n      d6 = Dot(point=np.array([p2[0], p2[1], 0.]) , color=BLUE)\n      \n      def update_path(path):\n            previous_path = path.copy()\n            previous_path.add_points_as_corners([dot.get_center()])\n            path.become(previous_path)\n      \n      self.add(rect)\n      self.wait()\n      self.add(dot,d6)\n      self.wait()\n      \n      #for i in range(2): \n      for i in range(len(final_coords_all)):\n        dot = Dot(point=np.array([p1[0],p1[1], 0.]) , color=BLUE)\n\n        path = VMobject()     \n        path.set_points_as_corners([dot.get_center(), dot.get_center()])\n        path.add_updater(update_path)\n        \n        self.add(path, dot)\n        dot.generate_target()\n        for j in range(len(final_coords_all[i])):\n          dot.target.shift(final_c
# ...
